# %%
import torch
import torchvision
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Download FashionMNIST dataset
training_dataset = torchvision.datasets.FashionMNIST("/tmp", train=True, transform=torchvision.transforms.ToTensor(), download=True)
testing_dataset = torchvision.datasets.FashionMNIST("/tmp", train=False, transform=torchvision.transforms.ToTensor(), download=True)

# %%
training_images = dataset.data
training_labels = dataset.targets

labels_dict = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

def show_data(image, label_index, title='', show_label=False):
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.imshow(image, cmap='gray')
    if show_label:
        ax.set_title(labels_dict[label_index], fontsize=10)
    fig.suptitle(title)

# %%
# Select an example image o play with
example_index = 101
example_image = training_images[example_index]
example_label = training_labels[example_index].item()

show_data(example_image, example_label, title=f"FashionMNIST image #{example_index}")
plt.savefig('example-data.svg')
plt.show()

# %% [markdown]
# An image is just a list of numbers

# %%
example_df = pd.DataFrame(example_image.numpy())

# %%
example_df.style.background_gradient(cmap='viridis')
